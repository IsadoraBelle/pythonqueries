# %% [markdown]
# 4.7: Deriving New Variables

# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %%
#Importing data set orders_products_combinedNEW.pkl
df_ords_prods_merged = pd.read_pickle(os.path.join(r'C:\Users\Sarah\Desktop\Data Course\08-12-2022 Instacart Basket Analysis\02 Data\Prepared Data\orders_products_combinedNEW.pkl'))
# Out:
# ---------------------------------------------------------------------------
# SystemError                               Traceback (most recent call last)
# SystemError: deallocated bytearray object has exported buffers
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17708\2753089803.py in <module>
#       1 #Importing data set orders_products_combinedNEW.pkl
# ----> 2 df_ords_prods_merged = pd.read_pickle(os.path.join(r'C:\Users\Sarah\Desktop\Data Course\08-12-2022 Instacart Basket Analysis\02 Data\Prepared Data\orders_products_combinedNEW.pkl'))
#
# ~\anaconda3\lib\site-packages\pandas\io\pickle.py in read_pickle(filepath_or_buffer, compression, storage_options)
#     203                     # We want to silence any warnings about, e.g. moved modules.
#     204                     warnings.simplefilter("ignore", Warning)
# ...

# %%
#Checking shape
df_ords_prods_merged.shape
# Out:
# (32404859, 15)

# %% [markdown]
# If-Statements with User-Defined Functions

# %%
#Creating a database subset
df = df_ords_prods_merged[:1000000]

# %%
#defining a new filter
def price_label(row):

  if row['prices'] <= 5:
    return 'Low-range product'
  elif (row['prices'] > 5) and (row['prices'] <= 15):
    return 'Mid-range product'
  elif row['prices'] > 15:
    return 'High range'
  else: return 'Not enough data'

# %%
df['price_range'] = df.apply(price_label, axis=1)
# Out:
# C:\Users\Sarah\AppData\Local\Temp\ipykernel_17708\2848743372.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price_range'] = df.apply(price_label, axis=1)

# %%
#checking shape
df.shape
# Out:
# (1000000, 16)

# %%
#checking how many items are in each range. 
df['price_range'].value_counts(dropna = False)
# Out:
# Mid-range product    756450
# Low-range product    243550
# Name: price_range, dtype: int64

# %%
#checking highest price
df['prices'].max()
# Out:
# 14.8

# %% [markdown]
# If-Statements with the loc() Function

# %%
#sorting prices high
df.loc[df['prices'] > 15, 'price_range_loc'] = 'High-range product'

# %%
#sorting prices mid-range
df.loc[(df['prices'] <= 15) & (df['prices'] > 5), 'price_range_loc'] = 'Mid-range product'

# %%
#sorting prices low
df.loc[df['prices'] <= 5, 'price_range_loc'] = 'Low-range product'

# %%
#checking how many items are in each range. 
df['price_range_loc'].value_counts(dropna = False)
# Out:
# Mid-range product    756450
# Low-range product    243550
# Name: price_range_loc, dtype: int64

# %%
#sorting prices high
df_ords_prods_merged.loc[df_ords_prods_merged['prices'] > 15, 'price_range_loc'] = 'High-range product'

# %%
#sorting prices mid-range
df_ords_prods_merged.loc[(df_ords_prods_merged['prices'] <= 15) & (df['prices'] > 5), 'price_range_loc'] = 'Mid-range product'

# %%
#sorting prices low
df_ords_prods_merged.loc[df_ords_prods_merged['prices'] <= 5, 'price_range_loc'] = 'Low-range product'

# %% [markdown]
# If-Statements with For-Loops

# %%
#finding days where the most orders take place
df_ords_prods_merged['orders_day_of_week'].value_counts(dropna = False)
# Out:
# 0    6204182
# 1    5660230
# 6    4496490
# 2    4213830
# 5    4205791
# 3    3840534
# 4    3783802
# Name: orders_day_of_week, dtype: int64

# %%
#creating busiest day column
result = []

for value in df_ords_prods_merged["orders_day_of_week"]:
  if value == 0:
    result.append("Busiest day")
  elif value == 4:
    result.append("Least busy")
  else:
    result.append("Regularly busy")

# %%
#printing loop
result
# Out:
# ['Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
# ...

# %%
#combining main document with new column 
df_ords_prods_merged['busiest_day'] = result
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17708\1341403591.py in <module>
#       1 #combining main document with new column
# ----> 2 df_ords_prods_merged['busiest_day'] = result
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    3653         else:
#    3654             # set column
# -> 3655             self._set_item(key, value)
#    3656
#    3657     def _setitem_slice(self, key: slice, value):
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in _set_item(self, key, value)
#    3830         ensure homogeneity.
#    3831         """
# -> 3832         value = self._sanitize_column(value)
#    3833
#    3834         if (
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in _sanitize_column(self, value)
#    4537         if is_list_like(value):
# ...

# %%
df_ords_prods_merged['busiest_day'].value_counts(dropna = False)

# %%
df_ords_prods_merged.shape

# %% [markdown]
# Question 2

# %% [markdown]
# Suppose your clients have changed their minds about the labels you created in your “busiest_day” column. Now, they want “Busiest day” to become “Busiest days” (plural). This label should correspond with the two busiest days of the week as opposed to the single busiest day. At the same time, they’d also like to know the two slowest days. Create a new column for this using a suitable method.

# %%
#finding days where the most orders take place
df_ords_prods_merged['orders_day_of_week'].value_counts(dropna = False)

# %%
#creating busiest days and slowest days column
result1 = []
for value in df_ords_prods_merged["orders_day_of_week"]:
  if value <= 1:
    result1.append("Busiest days")
  elif value>=3 and value<=4:
    result1.append("Slowest Days")
  else:
    result1.append("Regularly busy")

# %%
#printing loop
result1

# %%
#combining main document with new column 
df_ords_prods_merged['busiest_days'] = result1

# %%
df_ords_prods_merged.shape

# %% [markdown]
# Question 3

# %% [markdown]
# Check the values of this new column for accuracy. Note any observations in markdown format.

# %%
df_ords_prods_merged.head()

# %%
df_ords_prods_merged['busiest_days'].value_counts(dropna = False)

# %% [markdown]
# With the two new columns you can tell which is the least busy day, and by combining them you can see that the two busiest days almost have as many sales as the other 3 regularly busy days.

# %% [markdown]
# Question 4

# %% [markdown]
# When too many users make Instacart orders at the same time, the app freezes. The senior technical officer at Instacart wants you to identify the busiest hours of the day. Rather than by hour, they want periods of time labeled “Most orders,” “Average orders,” and “Fewest orders.” Create a new column containing these labels called “busiest_period_of_day.”

# %%
#finding hours where the most orders take place
df_ords_prods_merged['order_hour_of_day'].value_counts(dropna = False)

# %%
#creating column for number of orders
result2 = []
for value in df_ords_prods_merged['order_hour_of_day']:
  if value>=9 and value<=16:
    result2.append("Most orders")
  elif value <=6:
    result2.append("Average orders")
  else:
    result2.append("Fewest orders")

# %%
#printing loop
result2

# %%
#combining main document with new column 
df_ords_prods_merged['Most_orders'] = result2

# %%
df_ords_prods_merged.shape

# %%
df_ords_prods_merged.head()

# %% [markdown]
# Question 5

# %% [markdown]
# Print the frequency for this new column.

# %%
df_ords_prods_merged['Most_orders'].value_counts(dropna = False)

# %% [markdown]
# Question 5

# %% [markdown]
# Export your dataframe as a pickle file (since you added new columns) and store it correctly in your “Prepared Data” folder.

# %%
# Export data to pkl
df_ords_prods_merged.to_pickle(os.path.join(r'C:\Users\Sarah\Desktop\Data Course\08-12-2022 Instacart Basket Analysis\02 Data\Prepared Data\orders_products_combinedUPDATED.pkl'))
